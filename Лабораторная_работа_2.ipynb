# %% [markdown]
# <a href="https://colab.research.google.com/github/enikolaev/IT-and-Programming/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа 2. Управление ходом выполнения программы

# %% [markdown]
# Парчук Денис Геннадьевич, ИНБ-О-Б-26-2, Python

# %% [markdown]
# ## Задание

# %% [markdown]
# Необходимо вычислить значение выражения:
# $$Z= 1 - \frac{sin(X^2) + Y}{2}+\frac{cos(Y^3)+X}{3}-\frac{sin(X^4)+Y}{4}-\frac{cos(Y^5)+X}{5}-...$$
# Для каждой переменной необходимо вывести ее значение и тип.

# %% [markdown]
# ## Анализ выражения и определение переменных

# %% [markdown]
# Проанализируем выражение и определим переменные, которые потребуются для выполнения задания. Независимые переменные: $X, Y$. Переменная, которая должна быть вычислена на основе независимых: $Z$.
#
# Следует обратить внимание, что в выражении неизвестное число слагаемых, поэтому необходимо ввести переменную $N$ для представления количества слагаемых.
#
# Обратите внимание, что знаки слагаемых чередуются, а степени числителя и множетели знаменателя привязаны к порядковому номеру слагаемого.

# %% [markdown]
# ## Вычисление выражение, печать результатов

# %% [markdown]
# Код для вычисления значения выражения $Z$:

# %%
from math import *

X = 2
Y = 3
N = 10
Z = 1

for i in range(1, N + 1):

    if i % 2 == 1:
        chisl = sin(X ** (i + 1)) + Y
    else:
        chisl = cos(Y ** (i + 1)) + X

    znam = i + 1
    if i == 2:
        Z += chisl / znam
    else:
        Z -= chisl / znam
print(Z)
print("X = ", X, ", type(X) = ", type(X))
print("Y = ", Y, ", type(Y) = ", type(Y))
print("N = ", N, ", type(N) = ", type(N))
print("Z = ", Z, ", type(Z) = ", type(Z))
# Out:
# -2.5169630068400957

# %% [markdown]
# 1. Переменная — это именованная область памяти, которая хранит значение.
#
# 2. 99bottles — недопустимо (начинается с цифры)
#
#    r&d — недопустимо (символ & не разрешён).
#
# 3. Нет, это 2 разные переменные, так как Python чувствителен к регистру.
# 4. Нет, недопустима, так как значение присваивается переменной, а не наоборот.
# 5. Значение равняется val
# 6. valuel = int
#
#    value2 = float
#
#    value3 = float
#
#    value4 = int
#
#    value5 = str
# 7. 0
# 8. for х in range(0, 6):
#
#     print('Обожаю эту программу!')
# 9. 0
# 1
# 2
# 3
# 4
# 5
# 10. 2 3 4 5
# 11. 0 100 200 300 400 500
# 12. 10
# 9
# 8
# 7
# 6
# 13. Накопитель — это переменная, которая используется для суммирования значений в цикле.
# 14. Да, обязательно. Обычно инициализируют нулём для суммирования или единицей для умножения. Если не инициализировать, возникнет ошибка.
# 15. 15
# 16. 15 5
# 17. quantity += 1
#
#     days_left -= 5
#
#     price *= 10
#
#     price /= 2
# 18. fam = input("Введите вашу Фамилию: ")
# 19. sales = float(input('Введите объём продаж за неделю: '))
# 20. i = 0
#
#     while i < 10:
#
#       print(i)
