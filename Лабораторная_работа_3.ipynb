# %% [markdown]
# <a href="https://colab.research.google.com/github/enikolaev/IT-and-Programming/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа 3. Пользовательские функции

# %% [markdown]
# Парчук ИНБ-Б-О-2

# %% [markdown]
# ## Задание

# %% [markdown]
# Напишите функцию, которая печатает таблицу значений функции y=𝑥^2+3∙𝑥^3 для 𝑥∈[0,10]. Таблица печатает значения только для целых значений 𝑥 с шагом 1

# %% [markdown]
# ## Решение

# %% [markdown]
# ### Объявление функции

# %%
def tabl(x):
    for x in range(i, j + 1):
        y = x**2 + 3 * x**3
        print(y)
print(tabl(x))

# %% [markdown]
# ### Демонстрация использования функции

# %%
i = 0
j = 10
x = [i, j]
def tabl(x):
    for x in range(i, j + 1): #так как []
        y = x**2 + 3 * x**3
        print(y)
print(tabl(x))
# Out:
# 0
# 4
# 28
# 90
# 208
# 400
# 684
# 1078
# 1600
# 2268
# 3100
# None

# %% [markdown]
# Решите пример в соответствии с индивидуальным заданием

# %% [markdown]
# 1. Функция с возвратом значения(return) отличается от другой тем, что она, как ни странно, возвращает значение. То есть, отправляет результат туда, откуда была вызвана, чтобы его можно было использовать в переменных или выражениях.
# Пример:
# n = 4
# def res(x):
#     result = 0
#     for i in range(5):
#         result += x * 2
#     return result
# print(res(n))
#
# Функция напечатает результат 40 и запишет его как значение res(n). Теперь его можно присвоить любой другой переменной, или сразу использовать в выражении.
#
# 2. Это готовая функция, написанная другими разработчиками и включенная в состав стандартной библиотеки языка или сторонние пакеты. Такими являются math, turtle и прочие.
# 3. Потому что при их использовании нам не нужно знать, как именно они устроены внутри и какой сложный алгоритм там работает.
# 4. Эта инструкция генерирует случайное целое число в диапазоне от 1 до 100 включительно и присваивает полученное значение переменной x.
# 5. Это неверно построенная инструкция, которая вызовет ошибку, из за конфликта между скобками.
# 6. Эта функция инициализирует генератор случайных чисел
# 7. Вместо того чтобы копировать и вставлять один и тот же кусок кода в 10 разных местах, можно написать функцию один раз. Далее, когда нужно выполнить это действие, просто вызывам функцию по имени.
# 8. 1 часть - заголовок. Здесь мы инициализируем функцию(def), а затем даем ей имя и параметр внутри скобок, заканчиваем двоеточием. 2 часть - тело. Это блок, который содержит все инструкции, выполняемые при вызове функции. Можно закончить функцией return.
# 9. При определении функции в скобках параметру присваивается значение через знак =, которое не измениться без присваивания нового.
# 10. Рекурсия — это метод программирования, при котором функция вызывает саму себя для решения более мелкой задачки.
